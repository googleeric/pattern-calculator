# %%
import requests as req
import pandas as pd

# %%
df = pd.read_csv('https://assets.upstox.com/market-quote/instruments/exchange/complete.csv.gz')

df.columns
# Out:
# Index(['instrument_key', 'exchange_token', 'tradingsymbol', 'name',
#        'last_price', 'expiry', 'strike', 'tick_size', 'lot_size',
#        'instrument_type', 'option_type', 'exchange'],
#       dtype='object')

# %%
df['exchange'].unique()
# Out:
# array(['NCD_FO', 'BSE_EQ', 'NSE_EQ', 'BSE_FO', 'NSE_FO', 'BCD_FO',
#        'BSE_INDEX', 'MCX_FO', 'NSE_COM', 'NSE_INDEX'], dtype=object)

# %%
df[(df['instrument_key'] == 'BHARAT ELECTRONICS LTD') & (df['exchange'] == 'BSE_EQ')]
# Out:
# Empty DataFrame
# Columns: [instrument_key, exchange_token, tradingsymbol, name, last_price, expiry, strike, tick_size, lot_size, instrument_type, option_type, exchange]
# Index: []

# %%
df[df['exchange'] == 'NSE_EQ']
# Out:
#             instrument_key  exchange_token tradingsymbol  \
# 14     NSE_EQ|INE869I01013           21195          GTPL
# 43     NSE_EQ|INE399C01030           11689      SUPRAJIT
# 55     NSE_EQ|INE0MJQ01020           12986       PRITIKA
# 91     NSE_EQ|INE0LLY01014           27213          EIEL
# 93     NSE_EQ|INE0J1E01027           10293           KCK
# ...                    ...             ...           ...
# 96421  NSE_EQ|IN1620210212            8580        74HR37
# 96444  NSE_EQ|INE818A01017           13598         SELAN
# 96452  NSE_EQ|IN1620210204            8575       726HR32
# 96507  NSE_EQ|IN1120220018           13372       762AR32
# 96509  NSE_EQ|INE204E01012            3389       AGARIND
#
#                            name  last_price expiry  strike  tick_size  \
# 14         GTPL HATHWAY LIMITED      105.31    NaN     NaN       0.01
# 43     SUPRAJIT ENGINEERING LTD      388.95    NaN     NaN       0.05
# ...
